# %%
#Q1
#Get is used to get data given by the client through the url.
#Post is used to get the data given by the client through the form.

# %%
#Q2
#request is used in flask to get data from clients through either of Get or Post.

# %%
#Q3
#redirect() is used to redirect the client to a different url.

# %%
#Q4
#templetes in python allows us to embed Python codes within HTML files.
#render_template() function in Flask is used to render HTML templates. It takes the name of the template file as an
#argument and can also pass additional data to the template.

# %% [markdown]
# #Q5
# ![Screenshot%202024-01-08%20at%2023.51.34.png](attachment:Screenshot%202024-01-08%20at%2023.51.34.png)
